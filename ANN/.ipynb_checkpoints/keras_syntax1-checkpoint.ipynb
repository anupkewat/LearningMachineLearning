# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("data/fake_reg.csv")

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
sns.pairplot(df,palette="autumn")

# %%
#feature 2 has linearity on price

# %%
from sklearn.model_selection import train_test_split

# %%
X=df[['feature1','feature2']].values
y=df['price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
# array([[1001.63407565,  998.80950388],
#        [ 999.76150137,  998.41802414],
#        [ 998.2638401 , 1000.92030063],
#        ...,
#        [1000.47386523, 1001.44542815],
#        [ 998.8625673 ,  999.15662112],
#        [1000.55690247,  999.35441706]])

# %%
# normalize  and scale the data
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(X_train)

#scaler.fit(X_test)
# Out:
# MinMaxScaler()

# %%
ex=pd.Series(data=eks[0])
why=pd.Series(data=y_train)


# df1=pd.DataFrame(data=ex,label="x")

# %%
eks=X_train[:,:1].reshape(1,len(X_train[:,1:]))

# %%
len(eks)
# Out:
# 1

# %%
X_train[:,1:].reshape(1,len(X_train[:,:1]))
# Out:
# array([[ 998.80950388,  998.41802414, 1000.92030063, 1002.20349379,
#          999.18061663, 1000.33504949, 1000.82325733,  999.71177054,
#         1000.33095384, 1000.35581475, 1001.18884035, 1000.29657813,
#          999.92802204,  999.93182339,  998.00969558, 1000.95448606,
#          999.67147785,  999.41729535, 1000.4875262 ,  999.89891546,
#         1001.07656828, 1002.03006563,  999.07415608,  998.2842458 ,
#          998.97663312, 1000.63071177,  998.89345427,  998.36712108,
#         1000.43040636, 1000.40191806,  998.63711842,  999.84959104,
#         1001.02270174,  999.92670081,  999.7660962 ,  999.42506324,
#         1000.61225972, 1000.26679247,  999.53343531,  999.13753504,
#          999.91256794, 1001.07788972,  998.79816656,  999.62733333,
#         1000.56275439,  997.87857423, 1000.44118737,  999.01185508,
#         1000.21598456,  999.42160543,  998.92486845, 1000.00467249,
#         1000.92055357, 1001.6638687 , 1000.63782898,  998.08127814,
# ...

# %%
finx=X_train[:,1:].reshape(1,len(X_train[:,:1]))

# %%
sx=pd.Series(finx[0])

# %%
sx
# Out:
# 0       998.809504
# 1       998.418024
# 2      1000.920301
# 3      1002.203494
# 4       999.180617
#           ...
# 695    1000.826203
# 696    1000.312159
# 697    1001.445428
# 698     999.156621
# 699     999.354417
# Length: 700, dtype: float64

# %%
dftest=pd.DataFrame()

# %%
dftest['x']=sx
dftest['y']=why

# %%
dftest
# Out:
#                x           y
# 0     998.809504  461.140624
# 1     998.418024  353.783395
# 2    1000.920301  510.878579
# 3    1002.203494  711.657773
# 4     999.180617  439.386678
# ..           ...         ...
# 695  1000.826203  584.928438
# 696  1000.312159  553.123878
# 697  1001.445428  646.421371
# 698   999.156621  367.045617
# 699   999.354417  470.890670
#
# [700 rows x 2 columns]

# %%
sns.pairplot(data=dftest)
